# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO(r"E:\FCI\fourth level\computer vision\task5\image\yolov8n.pt")
video_path = r"E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4"
results = model(source=video_path,conf=0.4,stream=True, show=True,save=True)

for result in results:
    frame = result.plot()  
    cv2.imshow("Processing", frame)
# Out:
# video 1/1 (frame 1/466) E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4: 384x640 1 giraffe, 95.6ms
# video 1/1 (frame 2/466) E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4: 384x640 1 giraffe, 94.5ms
# video 1/1 (frame 3/466) E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4: 384x640 1 giraffe, 58.9ms
# video 1/1 (frame 4/466) E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4: 384x640 1 giraffe, 63.7ms
# video 1/1 (frame 5/466) E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4: 384x640 1 giraffe, 65.6ms
# video 1/1 (frame 6/466) E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4: 384x640 1 giraffe, 64.3ms
# video 1/1 (frame 7/466) E:\FCI\fourth level\computer vision\task5\video\4962323-uhd_3840_2160_30fps.mp4: 384x640 1 giraffe, 64.2ms
# ...
