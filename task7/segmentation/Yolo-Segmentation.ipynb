# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt


model = YOLO(r"E:\FCI\fourth level\computer vision\task7\segmentation\yolov8n-seg.pt")
results = model(r"E:\FCI\fourth level\computer vision\task7\animal.jpg",conf=0.4 ,show=True)
# Out:
# image 1/1 E:\FCI\fourth level\computer vision\task7\animal.jpg: 640x640 1 dog, 902.5ms
# Speed: 62.6ms preprocess, 902.5ms inference, 118.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
import os 
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
